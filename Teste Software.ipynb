# %%
import sys 
import os
script_dir = os.path.abspath('..')        #Alterar o caminho se necessário
if script_dir not in sys.path:
    sys.path.append(script_dir)

import doestat_dev as doe
import pandas as pd

# %%
help(doe)
# Out:
# Help on module doestat_dev:
#
# NAME
#     doestat_dev
#
# CLASSES
#     builtins.object
#         Analysis
#         Cp
#         DataPrint
#         RegressionAnalysis
#         Surface
#         Taguchi
#
#     class Analysis(builtins.object)
#      |  Analysis(x, y, effect_error=0, t=0)
#      |
#      |  Class -> Analysis(X, y)
#      |
#      |  A class designed to evaluate factorial planning effects, providing insights into the contributions of
#      |  individual factors and their interactions in an experimental design.
#      |
#      |  Features:
#      |  - Factorial Effect Analysis: Calculates and visualizes the effects of factors in a factorial design.
#      |  - Probability Graph: Displays the distribution of effects using a Gaussian-based probability plot.
#      |  - Percentage Contributions: Quantifies the relative contributions of each effect to the overall variability.
# ...
